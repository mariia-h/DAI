# %% [markdown]
# ## <span style="color:#4375c7">DAI</span>
# ***
# *Course materials are for educational purposes only. Nothing contained herein should be considered investment advice or an opinion regarding the suitability of any security. For more information about this course, please contact us.*
# ***
#
#
# ## Unsupervised learning
#
# Unsupervised learning includes methods and algorithms for finding patterns in unlabeled data sets. The two main tasks of unsupervised learning are to find the best representation of the data, known as unsupervised transformations, and to divide the data into different groups, known as clustering. The result of the learning algorithms is unknown, there is no supervisor training the algorithm. Unsupervised learning can be used to gain a deeper understanding of the data or to split the data, and is also useful for preprocessing data for supervised algorithms.
#
# ### Session contents:
# 1. **[Notebook set up](#setup)**
# 2. **[Cluster analysis](#ClustAna)**
#     - [k-means clustering](#kmeans)
#     - [Hierachical clustering](#Hclustering)
#     - [Dendrogram](#Dendrogram)
#     - [Number of clusters]("Ncluster")
#
# 3. **[Hands on]("#handson")**
# 4. **[Session takeaways](#takeaways)**
#
# ***

# %% [markdown]
# ## 1. Notebook set up  <a name="setup"></a>
# As a first step, import the Python libraries Pandas, NumPy, Matplotlib, mglearn and modules from SciPy, sklearn and IPython. In case you cannot import any library: open a new terminal and install the module via pip: `pip install mglearn`.
# The examples using the library mglearn are based on Müller et al. [1].

# %%
#!pip install -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt #ensure that the required packages are installed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import mglearn
from IPython import display
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, ward, average
from sklearn.cluster import AgglomerativeClustering
# Out:
# Collecting pandas>=2.2.1 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 7))
#   Using cached pandas-3.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=2.1.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 8))
#   Using cached numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting openpyxl>=3.1.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 9))
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting plotly>=5.20.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 10))
#   Using cached plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting matplotlib>=3.8.3 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.4 MB/s eta 0:00:00
# Collecting scikit-learn>=1.4.1 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 12))
#   Using cached scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting mglearn>=0.2.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 13))
#   Using cached mglearn-0.2.0-py2.py3-none-any.whl.metadata (628 bytes)
# Collecting graphviz>=0.20.3 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 14))
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting keras>=3.1.1 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tensorflow>=2.16.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached tensorflow-2.21.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting openai>=1.14.3 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Downloading openai-2.34.0-py3-none-any.whl.metadata (31 kB)
# Collecting empiricaldist>=0.7.2 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 18))
#   Using cached empiricaldist-0.9.0-py3-none-any.whl
# Collecting networkx>=3.2.1 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 19))
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting seaborn>=0.13.2 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 20))
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting cryptography>=46.0.7 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 21))
#   Downloading cryptography-48.0.0-cp311-abi3-macosx_10_9_universal2.whl.metadata (4.3 kB)
# Requirement already satisfied: Pygments>=2.20.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 22)) (2.20.0)
# Collecting requests>=2.33.0 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 23))
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting tables (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached tables-3.11.1-cp311-abi3-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting statsmodels (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 25))
#   Using cached statsmodels-0.14.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting plotnine (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 26))
#   Downloading plotnine-0.15.4-py3-none-any.whl.metadata (9.6 kB)
# Collecting stargazer (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 27))
#   Using cached stargazer-0.0.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting dowhy (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached dowhy-0.14-py3-none-any.whl.metadata (18 kB)
# Collecting wrds (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29))
#   Using cached wrds-3.5.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting beautifulsoup4 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 30))
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting newsapi-python (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 31))
#   Using cached newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting lxml (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 32))
#   Using cached lxml-6.1.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.0 kB)
# Collecting tqdm (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 33))
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from pandas>=2.2.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 7)) (2.9.0.post0)
# Collecting et-xmlfile (from openpyxl>=3.1.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 9))
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting narwhals>=1.15.1 (from plotly>=5.20.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 10))
#   Using cached narwhals-2.20.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from plotly>=5.20.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 10)) (26.2)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Collecting pillow>=8 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.8.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 11))
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting scipy>=1.10.0 (from scikit-learn>=1.4.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 12))
#   Using cached scipy-1.17.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn>=1.4.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 12))
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn>=1.4.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 12))
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting imageio (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 13))
#   Using cached imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting absl-py (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting rich (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting h5py (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached h5py-3.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting optree (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Downloading optree-0.19.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (32 kB)
# Collecting ml-dtypes (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Collecting astunparse>=1.6.0 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting setuptools (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16)) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting typing_extensions>=3.6.6 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting wrapt>=1.11.0 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting h5py (from keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached h5py-3.14.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached jiter-0.14.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting sniffio (from openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cffi>=2.0.0 (from cryptography>=46.0.7->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 21))
#   Using cached cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.33.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 23))
#   Using cached charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests>=2.33.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 23))
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.33.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 23))
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests>=2.33.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 23))
#   Using cached certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting numexpr>=2.6.2 (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached numexpr-2.14.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting py-cpuinfo (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting blosc2>=2.3.0 (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached blosc2-4.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting patsy>=0.5.6 (from statsmodels->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 25))
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting mizani~=0.14.0 (from plotnine->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 26))
#   Using cached mizani-0.14.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting causal-learn>=0.1.3.0 (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached causal_learn-0.1.4.5-py3-none-any.whl.metadata (4.6 kB)
# Collecting cvxpy<2.0.0,>=1.7.1 (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached cvxpy-1.8.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (9.6 kB)
# Collecting cython>=3.0 (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached cython-3.2.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting numba>=0.59 (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Downloading numba-0.65.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (2.9 kB)
# Collecting scipy>=1.10.0 (from scikit-learn>=1.4.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 12))
#   Using cached scipy-1.15.3-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting sympy>=1.10.1 (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting ipython<=9.8.0 (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29))
#   Using cached ipython-9.8.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting pandas>=2.2.1 (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 7))
#   Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting psycopg2-binary<2.10,>=2.9 (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29))
#   Using cached psycopg2_binary-2.9.12-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting sqlalchemy<2.1,>=2 (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29))
#   Using cached sqlalchemy-2.0.49-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting pytz>=2020.1 (from pandas>=2.2.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 7))
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.2.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 7))
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 30))
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow>=2.16.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 16))
#   Using cached wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting ndindex (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached ndindex-1.10.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting msgpack (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 24))
#   Using cached msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting pydot (from causal-learn>=0.1.3.0->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached pydot-4.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting momentchi2 (from causal-learn>=0.1.3.0->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached momentchi2-0.1.8-py3-none-any.whl.metadata (6.1 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=46.0.7->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 21))
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting osqp>=1.0.0 (from cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached osqp-1.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting clarabel>=0.5.0 (from cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached scs-3.2.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting highspy>=1.11.0 (from cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached highspy-1.14.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: decorator>=4.3.2 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (5.15.0)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba>=0.59->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached llvmlite-0.47.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3,>=1.9.0->openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached pydantic_core-2.46.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai>=1.14.3->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 17))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.10.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.8.7)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.1.1->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 15))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting jinja2 (from osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/kiraschoenhuette/Documents/01_Arbeit_und_Projekte/01_Lehrstuhl_Orga/50_Lehre/DAI/DAI_SummerTerm26/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 29)) (0.2.3)
# Collecting MarkupSafe>=2.0 (from jinja2->osqp>=1.0.0->cvxpy<2.0.0,>=1.7.1->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements.txt (line 28))
#   Using cached markupsafe-3.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Using cached numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached plotly-6.7.0-py3-none-any.whl (9.9 MB)
# Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 11.1 MB/s eta 0:00:0000:0100:01
# Using cached scikit_learn-1.8.0-cp312-cp312-macosx_12_0_arm64.whl (8.1 MB)
# Using cached mglearn-0.2.0-py2.py3-none-any.whl (581 kB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Using cached keras-3.14.0-py3-none-any.whl (1.6 MB)
# Using cached tensorflow-2.21.0-cp312-cp312-macosx_12_0_arm64.whl (223.5 MB)
# Downloading openai-2.34.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading cryptography-48.0.0-cp311-abi3-macosx_10_9_universal2.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 11.6 MB/s eta 0:00:0000:0100:01
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached tables-3.11.1-cp311-abi3-macosx_11_0_arm64.whl (6.3 MB)
# Using cached statsmodels-0.14.6-cp312-cp312-macosx_11_0_arm64.whl (10.0 MB)
# Downloading plotnine-0.15.4-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.8 MB/s eta 0:00:00a 0:00:01
# Using cached stargazer-0.0.7-py3-none-any.whl (15 kB)
# Using cached dowhy-0.14-py3-none-any.whl (403 kB)
# Using cached wrds-3.5.0-py3-none-any.whl (16 kB)
# Using cached pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Using cached lxml-6.1.0-cp312-cp312-macosx_10_13_universal2.whl (8.6 MB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached blosc2-4.1.2-cp312-cp312-macosx_11_0_arm64.whl (4.1 MB)
# Using cached causal_learn-0.1.4.5-py3-none-any.whl (204 kB)
# Using cached certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl (181 kB)
# Using cached charset_normalizer-3.4.7-cp312-cp312-macosx_10_13_universal2.whl (311 kB)
# Using cached contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cvxpy-1.8.2-cp312-cp312-macosx_10_13_universal2.whl (1.7 MB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached cython-3.2.4-cp312-cp312-macosx_11_0_arm64.whl (3.0 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.80.0-cp312-cp312-macosx_11_0_universal2.whl (12.0 MB)
# Using cached h5py-3.14.0-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 3.0 MB/s eta 0:00:00
# Using cached ipython-9.8.0-py3-none-any.whl (621 kB)
# Using cached jiter-0.14.0-cp312-cp312-macosx_11_0_arm64.whl (315 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached mizani-0.14.4-py3-none-any.whl (133 kB)
# Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl (676 kB)
# Using cached narwhals-2.20.0-py3-none-any.whl (449 kB)
# Downloading numba-0.65.1-cp312-cp312-macosx_12_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 16.1 MB/s eta 0:00:0000:0100:01
# Using cached numexpr-2.14.1-cp312-cp312-macosx_11_0_arm64.whl (152 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
# Using cached protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Using cached psycopg2_binary-2.9.12-cp312-cp312-macosx_11_0_arm64.whl (3.8 MB)
# Using cached pydantic-2.13.3-py3-none-any.whl (471 kB)
# Using cached pydantic_core-2.46.3-cp312-cp312-macosx_11_0_arm64.whl (2.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 kB 10.5 MB/s eta 0:00:00a 0:00:01
# Using cached scipy-1.15.3-cp312-cp312-macosx_14_0_arm64.whl (22.4 MB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Using cached sqlalchemy-2.0.49-cp312-cp312-macosx_11_0_arm64.whl (2.2 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 10.3 MB/s eta 0:00:00
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached wrapt-2.1.2-cp312-cp312-macosx_11_0_arm64.whl (61 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached imageio-2.37.3-py3-none-any.whl (317 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.1-cp312-cp312-macosx_11_0_arm64.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 16.0 MB/s eta 0:00:00
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached clarabel-0.11.1-cp39-abi3-macosx_11_0_arm64.whl (935 kB)
# Using cached highspy-1.14.0-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
# Using cached llvmlite-0.47.0-cp312-cp312-macosx_11_0_arm64.whl (37.2 MB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached osqp-1.1.1-cp312-cp312-macosx_11_0_arm64.whl (302 kB)
# Using cached scs-3.2.11-cp312-cp312-macosx_11_0_arm64.whl (96 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached wheel-0.47.0-py3-none-any.whl (32 kB)
# Using cached momentchi2-0.1.8-py3-none-any.whl (11 kB)
# Using cached msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl (85 kB)
# Using cached ndindex-1.10.1-cp312-cp312-macosx_11_0_arm64.whl (176 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Using cached pydot-4.0.1-py3-none-any.whl (37 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: stargazer, pytz, py-cpuinfo, namex, mpmath, libclang, flatbuffers, wrapt, wheel, urllib3, tzdata, typing_extensions, tqdm, threadpoolctl, termcolor, sympy, soupsieve, sniffio, setuptools, pyparsing, pycparser, psycopg2-binary, protobuf, pillow, opt_einsum, numpy, networkx, ndindex, narwhals, msgpack, mdurl, MarkupSafe, lxml, llvmlite, kiwisolver, joblib, jiter, idna, h11, graphviz, google_pasta, gast, fonttools, et-xmlfile, distro, cython, cycler, charset_normalizer, certifi, annotated-types, absl-py, typing-inspection, sqlalchemy, scipy, requests, pydot, pydantic-core, plotly, patsy, pandas, optree, openpyxl, numexpr, numba, ml-dtypes, markdown-it-py, jinja2, ipython, imageio, httpcore, highspy, h5py, grpcio, contourpy, cffi, beautifulsoup4, astunparse, anyio, wrds, statsmodels, scs, scikit-learn, rich, pydantic, osqp, newsapi-python, momentchi2, mizani, matplotlib, httpx, cryptography, clarabel, blosc2, tables, seaborn, plotnine, openai, mglearn, keras, empiricaldist, cvxpy, causal-learn, tensorflow, dowhy
#   Attempting uninstall: ipython
#     Found existing installation: ipython 9.13.0
#     Uninstalling ipython-9.13.0:
#       Successfully uninstalled ipython-9.13.0
# Successfully installed MarkupSafe-3.0.3 absl-py-2.4.0 annotated-types-0.7.0 anyio-4.13.0 astunparse-1.6.3 beautifulsoup4-4.14.3 blosc2-4.1.2 causal-learn-0.1.4.5 certifi-2026.4.22 cffi-2.0.0 charset_normalizer-3.4.7 clarabel-0.11.1 contourpy-1.3.3 cryptography-48.0.0 cvxpy-1.8.2 cycler-0.12.1 cython-3.2.4 distro-1.9.0 dowhy-0.14 empiricaldist-0.9.0 et-xmlfile-2.0.0 flatbuffers-25.12.19 fonttools-4.62.1 gast-0.7.0 google_pasta-0.2.0 graphviz-0.21 grpcio-1.80.0 h11-0.16.0 h5py-3.14.0 highspy-1.14.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 imageio-2.37.3 ipython-9.8.0 jinja2-3.1.6 jiter-0.14.0 joblib-1.5.3 keras-3.14.0 kiwisolver-1.5.0 libclang-18.1.1 llvmlite-0.47.0 lxml-6.1.0 markdown-it-py-4.0.0 matplotlib-3.10.9 mdurl-0.1.2 mglearn-0.2.0 mizani-0.14.4 ml-dtypes-0.5.4 momentchi2-0.1.8 mpmath-1.3.0 msgpack-1.1.2 namex-0.1.0 narwhals-2.20.0 ndindex-1.10.1 networkx-3.6.1 newsapi-python-0.2.7 numba-0.65.1 numexpr-2.14.1 numpy-2.4.4 openai-2.34.0 openpyxl-3.1.5 opt_einsum-3.4.0 optree-0.19.1 osqp-1.1.1 pandas-2.2.3 patsy-1.0.2 pillow-12.2.0 plotly-6.7.0 plotnine-0.15.4 protobuf-7.34.1 psycopg2-binary-2.9.12 py-cpuinfo-9.0.0 pycparser-3.0 pydantic-2.13.3 pydantic-core-2.46.3 pydot-4.0.1 pyparsing-3.3.2 pytz-2026.2 requests-2.33.1 rich-15.0.0 scikit-learn-1.8.0 scipy-1.15.3 scs-3.2.11 seaborn-0.13.2 setuptools-82.0.1 sniffio-1.3.1 soupsieve-2.8.3 sqlalchemy-2.0.49 stargazer-0.0.7 statsmodels-0.14.6 sympy-1.14.0 tables-3.11.1 tensorflow-2.21.0 termcolor-3.3.0 threadpoolctl-3.6.0 tqdm-4.67.3 typing-inspection-0.4.2 typing_extensions-4.15.0 tzdata-2026.2 urllib3-2.6.3 wheel-0.47.0 wrapt-2.1.2 wrds-3.5.0
#
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 2. Cluster analysis <a id='ClustAna'></a>
#
# **Cluster analysis** or **clustering** describes methods that divide a set of objects into many subsets, called **clusters**. Objects in a cluster should be as similar as possible to each other, while objects in different clusters should be distinctly different from each other. Given a set of objects $ I = \{I_1, \dots, I_N\}$ and some associated features $x = \{x_1, \dots, x_p\}$, we can perform a cluster analysis. We can sum up the features of the objects in a **feature matrix**
#
# $$X = \begin{bmatrix} x_{1,1} & \dots & x_{1,p} \\ \vdots & & \vdots \\ x_{N,1} & \dots & x_{N,p} \end{bmatrix}.$$
#
# Some clustering methods use this feature matrix directly in the clustering process, while others use **similarity** or **distance measures** of the feature values.
#
# For all methods, the following holds: One object should be assigned to one of $n$ clusters. A calculated set of clusters is called **partition**. For such a partition $\Gamma = \{C_1, C_2, \dots, C_n\}$ of a set of objects $I$ holds:
#
# \begin{align}
# \bigcup^n_{l=1} C_l = I, \quad C_l \; \cap \; C_r = \emptyset,\quad l \ne r .
# \end{align}
#
# Different methods can be used to generate partitions of clusters.
#
# ###  K-means<a id='kmeans'></a>
#
#
# **K-means** is one of the most widely used clustering algorithms. This algorithm aims to find the cluster centers that are representative of certain "regions" in the data. The number of clusters must be given to the algorithm. The algorithm can be described as follows
#
#
# 1. Initialize random data points as cluster centers
# 2. Assign every data point to the nearest cluster by calculating the distance to the different cluster centers
# 3. Set the cluster centers as the mean of the assigned data points
# 4. Repeat step 2) and 3) until the assignment of the data points to the clusters does not change anymore.
#
# The following plot visualizes the k-means clustering process.

# %%
mglearn.plots.plot_kmeans_algorithm()

# %% [markdown]
# **K-means** minimizes the within-cluster variances (the squared Euclidean distances). This results in the partitioning of the data space into **Voroni cells**. Each Voroni cell contains one cluster. The following example shows the boundaries of the clusters. Each Voroni cell is marked with a different color.

# %%
mglearn.plots.plot_kmeans_boundaries()

# %% [markdown]
# We can use **k-means** with the scikit-learn package. We use the same synthetic data as in the previous example and set the number of clusters to 3 (the default by n_clusters is 8).

# %%
X, _ = make_blobs(random_state=1)

# Clustering model and fit:
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)

print("First 5 datapoints of X:")
print(X[:5])
print("Cluster-Assingment:\n{}".format(kmeans.labels_))
# Out:
# First 5 datapoints of X:
# [[ -0.79415228   2.10495117]
#  [ -9.15155186  -4.81286449]
#  [-11.44182631  -4.45781441]
#  [ -9.76761777  -3.19133737]
#  [ -4.53655648  -8.40186288]]
# Cluster-Assingment:
# [1 2 2 2 0 0 0 2 1 1 2 2 0 1 0 0 0 1 2 2 0 2 0 1 2 0 0 1 1 0 1 1 0 1 2 0 2
#  2 2 0 0 2 1 2 2 0 1 1 1 1 2 0 0 0 1 0 2 2 1 1 2 0 0 2 2 0 1 0 1 2 2 2 0 1
#  1 2 0 0 1 2 1 2 2 0 1 1 1 1 2 1 0 1 1 2 2 0 0 1 0 1]

# %% [markdown]
# We receive the same partition as before:

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], kmeans.labels_, markers='o')
mglearn.discrete_scatter(kmeans.cluster_centers_[:, 0],
                         kmeans.cluster_centers_[:, 1], [0, 1, 2],
                         markers='^',
                         markeredgewidth=2)
plt.show()

# %% [markdown]
# New data points can be assigned to the clusters using the **.predict()** method.
#
# If we choose a different cluster threshold, we get different results:

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
# two clusters:
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
assignments = kmeans.labels_
mglearn.discrete_scatter(X[:, 0], X[:, 1], assignments, ax=axes[0])
axes[0].set_title("Two clusters")
# five clusters:
kmeans = KMeans(n_clusters=10)
kmeans.fit(X)
assignments = kmeans.labels_
mglearn.discrete_scatter(X[:, 0], X[:, 1], assignments, ax=axes[1])
axes[1].set_title("Ten clusters")
plt.show()

# %% [markdown]
# Even if we know the exact number of clusters, **k-means** performs poorly in some cases. For example, if the clusters have complex shapes, or if the data points cannot be easily separated, **k-means** cannot find a useful solution.

# %%
# Generate random data points:
X, y = make_blobs(random_state=170, n_samples=600)
rng = np.random.RandomState(74)
# transform the data:
transformation = rng.normal(size=(2, 2))
X = np.dot(X, transformation)
# Cluster the data in three clusters:
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_pred = kmeans.predict(X)
# plotting:
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm3)
plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            marker='^',
            c=[0, 1, 2],
            s=100,
            linewidth=2,
            cmap=mglearn.cm3)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()

# generate random data in moon shape:
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
# cluster data:
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
y_pred = kmeans.predict(X)
# plotting
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm2, s=60)
plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            marker='^',
            c=[mglearn.cm2(0), mglearn.cm2(1)],
            s=100,
            linewidth=2)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()

# %% [markdown]
# ###  Hierarchical clustering <a id='Hclustering'></a>
# **Hierarchical clustering** generates a partition of a given set of objects using an iterative hierarchical structure. Hierarchical clustering methods can be divided into two groups. First, the **divisive clustering**, a top-down approach, which starts with all objects forming a single cluster and then divides this cluster iteratively and hierarchically into smaller clusters until each object forms a single cluster. Second, the **agglomerative clustering**, a bottom-up approach, which startis by declaring each object a separate cluster, then merging the two most similar clusters until all objects form one large cluster. Each iterative step of hierarchical clustering creates a new partition. Thus, the clustering process generates for $p$ objects $p-1$ different partitions. The following example from Müller et al. [1] shows the iterative process of **agglomerative clustering**.

# %%
mglearn.plots.plot_agglomerative_algorithm()
plt.show()
mglearn.plots.plot_agglomerative()
plt.show()

# %% [markdown]
# The **homogeneity** of the clusters is measured by an index $h$. For small values of $h$, we get more homogeneity in each cluster, but also smaller clusters. Using this index has the advantage that it is not necessary to choose an explicit number of clusters or an explicit value of $h$ before implementing the clustering algorithm. $h$ can also be thought of as the cluster distance.

# %% [markdown]
# ###  Dendrogram <a id='Dendrogram'></a>
# All the different partitions can be visualized by a **dendrogram**. The number of clusters can be selected by cutting the dendrogram at a certain homogeneity index level. Let's visualize this with a short example of 15 data points in a two dimensional space.

# %%
from sklearn.cluster import AgglomerativeClustering

X, y = make_blobs(random_state=0, n_samples=15)
agg = AgglomerativeClustering(n_clusters=3, linkage="ward")
assignment = agg.fit_predict(X)
mglearn.discrete_scatter(X[:, 0], X[:, 1], assignment)
plt.xlabel("Feature 0")
plt.ylabel("Feature 0")
plt.show()

# %% [markdown]
# This dataset can be transformed into the following dendrogram:

# %%
X, y = make_blobs(random_state=0, n_samples=15)
linkage_array = ward(X)
dendrogram(linkage_array)
ax = plt.gca()
bounds = ax.get_xbound()
ax.plot(bounds, [10, 10], '--', c='k')
ax.plot(bounds, [6, 6], '--', c='k')
ax.text(bounds[1], 10.25, ' 2 clusters', va='center', fontdict={'size': 15})
ax.text(bounds[1], 6.25, ' 3 clusters', va='center', fontdict={'size': 15})
plt.xlabel("Cluster index")
plt.ylabel("Homogeneity index")
plt.title("Dendrogram")

plt.show()

# %% [markdown]
# The length of each branch of the dendrogram shows the distance between the homogeneity indices of the merged clusters.
# The longest branches are those marked by the dotted line "3 clusters". Merging these three clusters into two clusters would result in merging data points that are far apart. Therefore, we should choose a number of clusters greater than two.

# %% [markdown]
# ###  Distance measures <a id='Distance measures '></a>
# The similarity of two objects or classes can be measured by distance measures. Calculating the distance between objects always leads to a reduction of information. The most common distance measures for quantitative data are $L_p$ distance measures, such as the **city-block-distance** ($L_1$ distance):
#
# \begin{align}
# d_1(x_n,x_m) = \sum^p_{i=1} |x_{ni} - x_{mi}|
# \end{align}
#
# for objects $\{ x_{n1}, \dots, x_{np} \}$ and $\{ x_{m1}, \dots, x_{mp} \}$, or the **Euclidean distance**($L_2$ distance):
#
# \begin{align}
# d_2(x_n,x_m) = (\sum^p_{i=1} (x_{ni} - x_{mi})^2)^{1/2}
# \end{align}
#
# As an alternative, the **correlation** between two objects $\rho:=\frac{COV(x_n,x_m)}{\sigma_{x_n} \sigma_{x_m}}$ can be used as a distance measure:
#
# \begin{align}
# d_\rho(x_n,x_m) = 1- \rho(x_{n}, x_{m})
# \end{align}

# %% [markdown]
# ###  Linkage<a id='Linkage '></a>
# Each cluster describes a set of objects or data points. We now know how to calculate the distance between two objects, but how do we define the distance between two clusters?
#
# This can be done using the following linkage-methods.
#
# The **single-linkage** (Nearest Point Algorithm) for two clusters $C_n,Cm$ is defined as
#
# \begin{align}
#  h = \delta(C_n,C_m) = \min_{x_n \in C_n, x_m \in C_m} d(x_n,x_m)
# \end{align}
#
# The **single-linkage** calculates the smallest distance between all objects of the two clusters. This is done for all combinations of clusters. In an agglomerative clustering step, the two clusters with the smallest total distance are then merged.

# %%
# generate random data in moon shape:
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
# cluster data:
kmeans = AgglomerativeClustering(n_clusters=3, linkage="single")
kmeans.fit(X)
y_pred = kmeans.fit_predict(X)
# plotting
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm2, s=60)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.title("Single-linkage")
plt.show()

# %% [markdown]
# The **complete-linkage** (Farthest Point Algorithm) for two clusters $C_n,Cm$ is defined as
#
# \begin{align}
#  h = \delta(C_n,C_m) = \max_{x_n \in C_n, x_m \in C_m} d(x_n,x_m)
# \end{align}

# %%
# generate random data in moon shape:
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
# cluster data:
kmeans = AgglomerativeClustering(n_clusters=3, linkage="complete")
kmeans.fit(X)
y_pred = kmeans.fit_predict(X)
# plotting
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm2, s=60)

plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.title("Complete-linkage")
plt.show()

# %% [markdown]
# The **average-linkage**  for two clusters $C_n,Cm$ is defined as
#
# \begin{align}
#  h = \delta(C_n,C_m) = \frac{1}{N_n N_M} \sum_{x_n \in C_n} \sum_{x_m \in C_m} d(x_n,x_m)
# \end{align}
#
# with $N_n, N_m$ number ob objects in clusters $C_n,C_m$

# %%
# generate random data in moon shape:
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
# cluster data:
kmeans = AgglomerativeClustering(n_clusters=3, linkage="average")
kmeans.fit(X)
y_pred = kmeans.fit_predict(X)
# plotting
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm2, s=60)
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
#marker='^', c=[mglearn.cm2(0), mglearn.cm2(1)], s=100, linewidth=2)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.title("Average-linkage")
plt.show()

# %% [markdown]
# The **ward-linkage** (minimum variance method) for two clusters is defined as
#
# \begin{align}
# h =  \delta(C_n,C_m) = min \frac{N_n N_m}{N_n+N_m} d(\overline{x_n},\overline{x_m})^2
# \end{align}
#
# with $\overline{x_n},\overline{x_m}$ centers of the clusters $C_n,C_m$.

# %%
# generate random data in moon shape:
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
# cluster data:
kmeans = AgglomerativeClustering(n_clusters=3, linkage="ward")
kmeans.fit(X)
y_pred = kmeans.fit_predict(X)
# plotting
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap=mglearn.cm2, s=60)
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
#marker='^', c=[mglearn.cm2(0), mglearn.cm2(1)], s=100, linewidth=2)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.title("Ward-linkage")
plt.show()

# %% [markdown]
# ###  Number of clusters <a id='Nclusters'></a>
# How do we find the optimal number of clusters? The basic idea is that we want to find the natural partition of a given set of objects. In practice, the optimal number of clusters depends on the specific task and should be chosen carefully. There are many different methods to find the best partition of a data set (see Fahrmeir et al.[2]), and the method should be chosen depending on the specific task. We will discuss the **elbow method** and the **silhouette score**.
#
# Following Goutte et al. [4], one opportunity is to calculate all partitions and estimate the **within-cluster inertia** (variance) for every partition
# \begin{equation}
# I_W = 1/N \sum_{k=1}^K \sum_{j \in C_k} d^2(x_j,c_k)
# \end{equation}
# with cluster centers $c_k$ of K clusters $C_k \in \Gamma$, $N$ objects $x_j$ and the squared distance between two objects $d^2(.,.)$.
#
# $I_W$ is the average squared distance from a data point to its cluster center. We choose the number of clusters at the point where the marginal losses of $I_W$ change, creating an elbow in the graph.
# As the k-means algorithm is based on minimizing the within-cluster variance, we can apply the **elbow method** to find the "optimal" number of clusters.

# %%
import pandas as pd
X, y = make_blobs(random_state=0, n_samples=20)
elbow = []
for i in range(1, 21):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    elbow.append(kmeans.inertia_)
plt.plot(elbow)
plt.xticks(list(range(0, 20)))
plt.ylabel("Sum of squared distances ")
plt.xlabel("Number of clusters")
plt.show()

# %% [markdown]
# The inflection point (elbow) is at two clusters, indicating that a two-cluster model best fits the data set.

# %% [markdown]
# Another way to find the optimal number of clusters is to calculate the **silhouette coefficient**, following Rousseeuw [5]. Let $a$ be the mean distance between a data point and all other data points in the same cluster. Let $b$ be the mean distance between a data point and all other data points in the next nearest cluster. The silhouette coefficient for the data point $i$ is defined as
#
# \begin{equation}
# s(i) = \frac{b(i) -a(i)}{max (a(i),b(i))}
# \end{equation}
# The silhouette score is then defined as the average silhouette coefficient of the given partition. A higher silhouette score refers to a model with better-defined clusters. If a cluster only contains one object, we set $s$ to zero.

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances
from sklearn import datasets
import numpy as np
from sklearn.cluster import KMeans

X, y = make_blobs(random_state=0, n_samples=20)
silh_score = [0]
for i in range(2, 20):
    kmeans = KMeans(n_clusters=i).fit(X)
    labels = kmeans.labels_

    silh_score.append(metrics.silhouette_score(X, labels))

plt.plot(list(range(1, 20)), silh_score)
plt.xticks(list(range(1, 20)))
plt.ylabel("Silhouette Score ")
plt.xlabel("Number of clusters")
plt.show()
print(metrics.silhouette_score(X, labels))
# Out:
# 0.06531794820611325

# %% [markdown]
# We obtain the highest silhouette score with three clusters, indicating that a three-cluster model is the best fit for this data set. Comparing both methods leads to an optimal number of clusters between two and three, depending on the specific task.

# %%
X, y = make_blobs(random_state=0, n_samples=20)
agg = AgglomerativeClustering(n_clusters=2, linkage="ward")
assignment = agg.fit_predict(X)
mglearn.discrete_scatter(X[:, 0], X[:, 1], assignment)
plt.xlabel("Feature 0")
plt.ylabel("Feature 0")
plt.title("two clusters")
plt.show()
agg = AgglomerativeClustering(n_clusters=3, linkage="ward")
assignment = agg.fit_predict(X)
mglearn.discrete_scatter(X[:, 0], X[:, 1], assignment)
plt.xlabel("Feature 0")
plt.ylabel("Feature 0")
plt.title("three clusters")
plt.show()

# %% [markdown]
# ### Principal Component Analysis (PCA)
# With Principal Component Analysis (PCA), first introduced by Pearson (1901)[7], we are able to visualize the clusters although the data (e.g. daily stock returns) is high-dimensional. As an unsupervised learning method, PCA transforms a set of correlated variables into a smaller number of uncorrelated variables called principal components. The goal is to reduce the dimensionality of the dataset while retaining as much variance as possible, allowing us to project complex relationships into a 2D or 3D space. By focusing on the directions of maximum variance, PCA filters out noise and enables a clearer geometric interpretation of how data, such as stocks in the DAX, are grouped by the k-means algorithm based on their structural similarities.
#
# The objective of PCA is to find a set of $k$ principal components (vectors $w_j$) that maximize the variance of the projected data. For the first principal component ($w_1$), this is expressed as:
#
# $$w_1 = \arg \max_{\|w\|=1} \text{Var}(w^T X)$$
#
# In practice, this is solved by decomposing the covariance matrix $\Sigma$ of the data $X$, where:
#
# $$\Sigma w_j = \lambda_j w_j$$
#
# Here, $\lambda_j$ represents the **eigenvalue** (the amount of variance explained by that component), and $w_j$ is the **eigenvector** (the principal component direction).

# %% [markdown]
# ## 3. Session takeaways   <a name="takeaways"></a>
# *What have we learned in this session?*
#
# - We now understand the basic idea of clustering
# - We can perform k-means and hierarchical clustering methods
# - We understand the differences of linkages and distances between objects and clusters
# - We know different ways to estimate the best partition of your data
# - We can use clustering tools to find structures in your data
#
# *What's next?*
#
# During the hands-on session you are going to implement unsupervised learning algorithms using financial data.

# %% [markdown]
# To practice unsupervised learning algorithms in Python, please complete the datacamp course "Cluster Analysis in Python". Or do other courses on https://www.kaggle.com/learn

# %% [markdown]
# ## 4. Hands on  <a name="Handson"></a>
#
# ### Exercise 1
#
# a) Download the DAX stock tickers from https://en.wikipedia.org/wiki/DAX and drop the ticker for Siemens Energy.
#
# b) Download the DAX stock data from Yahoo Finance from January 1, 2018 to January 1, 2020 with the tickers and calculate the daily returns. Use the yfinance library.

# %%
import pandas as pd

# Load the DAX components table from Wikipedia
url = "https://en.wikipedia.org/wiki/DAX"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

tables = pd.read_html(url, storage_options=headers)
dax_table = tables[4]  # The 5th table contains the DAX listings

# Get ticker symbols
dax_tickers = dax_table["Ticker"].tolist()

# Remove Siemens Energy (ticker: ENR.DE on Yahoo Finance)
dax_tickers = [ticker for ticker in dax_tickers if ticker != "ENR.DE"]

print("DAX tickers without Siemens Energy:")
print(dax_tickers)
# Out:
# DAX tickers without Siemens Energy:
# ['ADS.DE', 'AIR.PA', 'ALV.DE', 'BAS.DE', 'BAYN.DE', 'BEI.DE', 'BMW.DE', 'BNR.DE', 'CBK.DE', 'CON.DE', 'DTG.DE', 'DBK.DE', 'DB1.DE', 'DHL.DE', 'DTE.DE', 'EOAN.DE', 'FRE.DE', 'FME.DE', 'G1A.DE', 'HNR1.DE', 'HEI.DE', 'HEN3.DE', 'IFX.DE', 'MBG.DE', 'MRK.DE', 'MTX.DE', 'MUV2.DE', 'PAH3.DE', 'QIA.DE', 'RHM.DE', 'RWE.DE', 'SAP.DE', 'G24.DE', 'SIE.DE', 'SHL.DE', 'SY1.DE', 'VOW3.DE', 'VNA.DE', 'ZAL.DE']

# %%
pip install yfinance -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# Set date range
start_date = "2018-01-01"
end_date = "2020-01-01"

# Download Adjusted Close prices
data = yf.download(dax_tickers, start=start_date, end=end_date)["Close"]

# Fill missing values forward
data_filled = data.ffill()

# Calculate daily returns
daily_returns = data_filled.pct_change()

daily_returns = daily_returns.dropna(axis=1, how='all')

daily_returns = daily_returns.dropna()

print("\nSample of daily returns:")
print(daily_returns.head())
# Out:
# [*************         28%                       ]  11 of 39 completed$DTG.DE: possibly delisted; no price data found  (1d 2018-01-01 -> 2020-01-01) (Yahoo error = "Data doesn't exist for startDate = 1514761200, endDate = 1577833200")
# [*********************100%***********************]  39 of 39 completed
#
# 2 Failed downloads:
# ['DHL.DE']: OperationalError('database is locked')
# ['DTG.DE']: possibly delisted; no price data found  (1d 2018-01-01 -> 2020-01-01) (Yahoo error = "Data doesn't exist for startDate = 1514761200, endDate = 1577833200")
# Sample of daily returns:
# Ticker        ADS.DE    AIR.PA    ALV.DE    BAS.DE   BAYN.DE    BEI.DE  \
# Date
# 2018-04-13  0.001427 -0.015706  0.004135  0.002025  0.001523  0.006265
# 2018-04-16  0.000475  0.004222  0.000317  0.000832 -0.006792 -0.005582
# 2018-04-17  0.011865  0.029874  0.013933  0.013422  0.027557  0.007125
# 2018-04-18  0.002345  0.016330  0.000000  0.008087 -0.003775 -0.002572
# 2018-04-19 -0.014974 -0.003806  0.002811  0.000698 -0.006979 -0.006662
#
# Ticker        BMW.DE    BNR.DE    CBK.DE    CON.DE  ...    QIA.DE    RHM.DE  \
# Date                                                ...
# 2018-04-13  0.015568  0.007098 -0.005918 -0.001331  ...  0.003782 -0.058323
# 2018-04-16 -0.007336 -0.002695 -0.001302 -0.012445  ... -0.004898  0.009494
# 2018-04-17  0.006177  0.007691  0.012668  0.021602  ...  0.011359  0.006270
# 2018-04-18 -0.004604  0.005569 -0.017292 -0.040529  ...  0.000374  0.001335
# 2018-04-19  0.000881 -0.006769  0.014789  0.020202  ... -0.004491  0.009333
#
# Ticker        RWE.DE    SAP.DE    SHL.DE    SIE.DE    SY1.DE    VNA.DE  \
# Date
# 2018-04-13  0.007246  0.002621  0.002465  0.001337  0.019899  0.019067
# 2018-04-16 -0.004316 -0.008753  0.001537 -0.006294  0.001549 -0.009355
# 2018-04-17  0.015414  0.014450  0.012891  0.014011  0.033086  0.007455
# 2018-04-18  0.028937  0.000904  0.009091  0.003786  0.001496  0.006660
# 2018-04-19  0.008299 -0.009374 -0.007808  0.014709  0.002391 -0.008821
#
# Ticker       VOW3.DE    ZAL.DE
# Date
# 2018-04-13  0.003850 -0.014107
# 2018-04-16 -0.028994 -0.018624
# 2018-04-17  0.015104  0.022911
# 2018-04-18 -0.002175 -0.014706
# 2018-04-19 -0.006194 -0.014466
#
# [5 rows x 37 columns]
# /var/folders/28/cjrpdnp161zfr_9y1jjd5vzr0000gn/T/ipykernel_62533/696435654.py:14: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = data_filled.pct_change()

# %%
daily_returns["BMW.DE"].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Exercise 2
#
# a) Perform a k-means clustering to group the DAX companies based on their stock market movements, visualize the clusters using PCA (with 2 and 3 components).
#
# b) Perform a hierarchical clustering to group the DAX companies based on their stock market movements using correlation as affinity and then plot the dendrogram.
#
# c) Optimize the number of clusters for both clustering algorithms based on the DAX data.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Scale the data before clustering
scaler = StandardScaler()
returns_scaled = scaler.fit_transform(daily_returns.T)  # transpose: shape (tickers, time)

# Fit KMeans with a chosen number of clusters (e.g., 4)
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans_labels = kmeans.fit_predict(returns_scaled)

# Store labels
kmeans_results = pd.DataFrame({
    "Company": daily_returns.columns,
    "Cluster": kmeans_labels
})

print("K-Means Clustering Results:")
print(kmeans_results.sort_values("Cluster"))
# Out:
# K-Means Clustering Results:
#     Company  Cluster
# 13  EOAN.DE        0
# 29   RWE.DE        0
# 11   DBK.DE        1
# 35  VOW3.DE        1
# 26  PAH3.DE        1
# 28   RHM.DE        1
# 21   IFX.DE        1
# 9    CON.DE        1
# 22   MBG.DE        1
# 6    BMW.DE        1
# 8    CBK.DE        1
# 5    BEI.DE        2
# 34   VNA.DE        2
# 19  HEN3.DE        2
# 30   SAP.DE        3
# 31   SHL.DE        3
# 32   SIE.DE        3
# 27   QIA.DE        3
# 33   SY1.DE        3
# 25  MUV2.DE        3
# 24   MTX.DE        3
# 23   MRK.DE        3
# 0    ADS.DE        3
# 18   HEI.DE        3
# 17   G24.DE        3
# 16   G1A.DE        3
# 15   FRE.DE        3
# 14   FME.DE        3
# 12   DTE.DE        3
# 10   DB1.DE        3
# 7    BNR.DE        3
# 4   BAYN.DE        3
# 3    BAS.DE        3
# 2    ALV.DE        3
# 1    AIR.PA        3
# 20  HNR1.DE        3
# 36   ZAL.DE        3

# %%
# Visualize the clusters using Principal Component Analysis (PCA)
# Reduce high-dimensional return data to 2D for plotting
pca = PCA(n_components=2)
coords = pca.fit_transform(returns_scaled)

# Initialize the plot dimensions
plt.figure(figsize=(14, 8))

# Create a scatter plot using the first two Principal Components
# Color points by their K-Means cluster assignment
plt.scatter(coords[:, 0], coords[:, 1], c=kmeans_labels, cmap='viridis', s=100, alpha=0.6)

# Map the Ticker symbols as labels next to their respective data points
for i, ticker in enumerate(daily_returns.columns):
    plt.annotate(ticker, (coords[i, 0], coords[i, 1]), 
                 textcoords="offset points", 
                 xytext=(5,5), 
                 ha='center', 
                 fontsize=10)

# Configure plot titles and axis labels representing the variance captured
plt.title('K-Means Clustering of Stocks (2D Projection)', fontsize=15)
plt.xlabel('Principal Component 1 (Direction of maximum variance)', fontsize=12)
plt.ylabel('Principal Component 2', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show() 


#-----------
# Increase dimensionality reduction to 3 components to capture more information
pca = PCA(n_components=3)
coords = pca.fit_transform(returns_scaled)

# Setup the 3D plotting environment
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

# Generate a 3D scatter plot
# This helps visualize clusters that may overlap in a 2D projection
scatter = ax.scatter(coords[:, 0], coords[:, 1], coords[:, 2], 
                     c=kmeans_labels, cmap='viridis', s=60, alpha=0.7)

# Add Ticker labels in 3D space
for i, ticker in enumerate(daily_returns.columns):
    ax.text(coords[i, 0], coords[i, 1], coords[i, 2], ticker, fontsize=8)

# Label axes according to the Principal Components
ax.set_title('3D K-Means Clustering of Stocks', fontsize=15)
ax.set_xlabel('PC 1 (Primary Variance)', fontsize=10)
ax.set_ylabel('PC 2', fontsize=10)
ax.set_zlabel('PC 3', fontsize=10)

plt.show()

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt

# Compute correlation-based distance between companies
distance_corr = pdist(daily_returns.T, metric='correlation')

# Hierarchical clustering using Ward linkage
linkage_matrix = linkage(distance_corr, method='ward')

# Plot dendrogram
plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix, labels=daily_returns.columns, leaf_rotation=90)
plt.title('Hierarchical Clustering Dendrogram (Correlation Distance)')
plt.xlabel('Company')
plt.ylabel('Distance')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import silhouette_score

inertia = []
silhouette_scores = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(returns_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(returns_scaled, labels))

# Plot Elbow
plt.figure()
plt.plot(K_range, inertia, 'bo-')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method (KMeans)')
plt.grid(True)
plt.show()

# Plot Silhouette Scores
plt.figure()
plt.plot(K_range, silhouette_scores, 'ro-')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method (KMeans)')
plt.grid(True)
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Define the range for testing clusters
K_range = range(2, 11)
hierarchical_silhouette_scores = []

# Iterate through different cluster counts
for k in K_range:
    # "Cut" the dendrogram to obtain k clusters based on the Ward linkage matrix
    # criterion='maxclust' ensures we get exactly k groups
    labels = fcluster(linkage_matrix, k, criterion='maxclust')
    
    # Calculate the Silhouette Score for the resulting partition
    score = silhouette_score(returns_scaled, labels)
    hierarchical_silhouette_scores.append(score)

# Plot the Silhouette Scores for Hierarchical Clustering
plt.figure(figsize=(10, 6))
plt.plot(K_range, hierarchical_silhouette_scores, 'go-', linewidth=2)
plt.title('Silhouette Method for Hierarchical Clustering (Ward)', fontsize=14)
plt.xlabel('Number of Clusters (k)', fontsize=12)
plt.ylabel('Silhouette Score', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Identify the optimal k
best_k = K_range[np.argmax(hierarchical_silhouette_scores)]
print(f"The optimal number of clusters based on Silhouette Score is: {best_k}")
# Out:
# The optimal number of clusters based on Silhouette Score is: 2

# %% [markdown]
# ### References
# ***
# [1] Müller, Andreas C., and Sarah Guido. Introduction to machine learning with Python: a guide for data scientists. " O'Reilly Media, Inc.", 2016.
#
# [2] Fahrmeir, L., Hamerle, A., & Tutz, G. (Eds.). (2015). Multivariate statistische verfahren. Walter de Gruyter GmbH & Co KG.
#
# [3] Hastie, T., Tibshirani, R., & Friedman, J. (2009). The elements of statistical learning: data mining, inference, and prediction. Springer Science & Business Media.
#
# [4] Goutte, C., Toft, P., Rostrup, E., Nielsen, F. A., & Hansen, L. K. (1999). On clustering fMRI time series. NeuroImage, 9(3), 298-310.
#
# [5] Rousseeuw, P. J. (1987). Silhouettes: a graphical aid to the interpretation and validation of cluster analysis. Journal of computational and applied mathematics, 20, 53-65.
#
# [6] Refer to the `statsmodels` library for user guides and extensive applications: https://www.statsmodels.org/dev/examples/index.html
#
# [7] Pearson, K. (1901). LIII. On lines and planes of closest fit to systems of points in space. The London, Edinburgh, and Dublin philosophical magazine and journal of science, 2(11), 559-572.
